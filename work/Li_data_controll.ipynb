# %%
from mp_api.client import MPRester

# %%
# API_KEYを読み込む
with open("MaterialsAPI_key.txt", "r") as file: # MaterialsAPI_key.txt へのパスは自分の環境に合わせて変更する
    API_KEY = file.read()

# %%
#API_KEYの設定
mpr = MPRester(API_KEY)

# %%
# battery explorerから取得できるデータの一覧
mpr.materials.insertion_electrodes.available_fields
# Out:
# ['battery_type',
#  'battery_id',
#  'thermo_type',
#  'battery_formula',
#  'working_ion',
#  'num_steps',
#  'max_voltage_step',
#  'last_updated',
#  'framework',
#  'framework_formula',
#  'elements',
#  'nelements',
#  'chemsys',
#  'formula_anonymous',
#  'warnings',
#  'formula_charge',
#  'formula_discharge',
#  'max_delta_volume',
#  'average_voltage',
#  'capacity_grav',
#  'capacity_vol',
#  'energy_grav',
#  'energy_vol',
#  'fracA_charge',
#  'fracA_discharge',
#  'stability_charge',
#  'stability_discharge',
#  'id_charge',
#  'id_discharge',
#  'host_structure',
#  'adj_pairs',
#  'material_ids',
#  'entries_composition_summary',
#  'electrode_object']

# %%
import pandas as pd

df = pd.read_csv("clean_Li_battery_data.csv")

# %%
# 取得したデータ数
df.shape
# Out:
# (2440, 26)

# %%
from sqlalchemy import create_engine

# %%
db_user = 'valley3'
db_password_file = './postgres_password.txt'
db_host = 'postgres'  # Dockerコンテナ内のPostgreSQLサービス名を指定します。
db_port = '5432'  # PostgreSQLのデフォルトポートは5432です。
db_name = 'material_db'

# %%
# PostgreSQLデータベースに接続
# パスワードをファイルから読み込む
with open(db_password_file, 'r') as f:
    db_password = f.read().strip()

# PostgreSQLの接続URIを作成
db_uri = f"postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"

# SQLAlchemyを使用してエンジンを作成し、DataFrameをPostgreSQLに挿入
engine = create_engine(db_uri)
df.to_sql('material_db', con=engine, if_exists='replace', index=False)

# 接続を閉じる
engine.dispose()

# %%
# PostgreSQLの接続URIを作成
db_uri = f"postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"

# SQLAlchemyを使用してエンジンを作成し、データベースからデータを読み込む
engine = create_engine(db_uri)

# データを読み込むSQLクエリを作成（ここでは全てのデータを読み込む例）
sql_query = "SELECT * FROM material_db"

# SQLクエリを実行し、データをDataFrameとして読み込む
df_from_db = pd.read_sql(sql_query, con=engine)

# 接続を閉じる
engine.dispose()

# 読み込んだデータを確認する
df_from_db
# Out:
#           battery_formula  num_steps  max_voltage_step  \
# 0            Li2-4CoNi3O8          2          0.221134
# 1            Li3-4CrNi3O8          1          0.000000
# 2        Li0-4Cu3Sb(PO4)4          1          0.000000
# 3            Li1-2Cu(HO)4          1          0.000000
# 4     Li0-4Mn3CuNi2(PO4)6          1          0.000000
# ...                   ...        ...               ...
# 2435          Li0-0.12VO2          1          0.000000
# 2436            Li0-2V3O7          1          0.000000
# 2437            Li0-1V2O5          1          0.000000
# 2438         Li0-0.67V2O5          2          0.641710
# 2439         Li0-1.29V2O5          1          0.000000
#
#                                               framework framework_formula  \
# 0                      {'Co': 1.0, 'Ni': 3.0, 'O': 8.0}           CoNi3O8
# 1                      {'Cr': 1.0, 'Ni': 3.0, 'O': 8.0}           CrNi3O8
# 2           {'Cu': 3.0, 'Sb': 1.0, 'P': 4.0, 'O': 16.0}       Cu3Sb(PO4)4
# 3                       {'Cu': 1.0, 'H': 4.0, 'O': 4.0}           Cu(HO)4
# 4     {'Mn': 3.0, 'Cu': 1.0, 'Ni': 2.0, 'P': 6.0, 'O...    Mn3CuNi2(PO4)6
# ...                                                 ...               ...
# 2435                               {'V': 1.0, 'O': 2.0}               VO2
# 2436                               {'V': 3.0, 'O': 7.0}              V3O7
# 2437                               {'V': 2.0, 'O': 5.0}              V2O5
# 2438                               {'V': 2.0, 'O': 5.0}              V2O5
# 2439                               {'V': 2.0, 'O': 5.0}              V2O5
#
#                           elements  nelements       chemsys formula_anonymous  \
# 0                ['Co', 'Ni', 'O']          3       Co-Ni-O             AB3C8
# 1                ['Cr', 'Ni', 'O']          3       Cr-Ni-O             AB3C8
# 2           ['Cu', 'Sb', 'P', 'O']          4     Cu-O-P-Sb          AB3C4D16
# 3                 ['Cu', 'H', 'O']          3        Cu-H-O             AB4C4
# 4     ['Mn', 'Cu', 'Ni', 'P', 'O']          5  Cu-Mn-Ni-O-P        AB2C3D6E24
# ...                            ...        ...           ...               ...
# 2435                    ['V', 'O']          2           O-V               AB2
# 2436                    ['V', 'O']          2           O-V              A3B7
# 2437                    ['V', 'O']          2           O-V              A2B5
# 2438                    ['V', 'O']          2           O-V              A2B5
# 2439                    ['V', 'O']          2           O-V              A2B5
#
#       formula_charge  ...   energy_vol  fracA_charge  fracA_discharge  \
# 0         Li2CoNi3O8  ...  2349.032129      0.142857         0.250000
# 1         Li3CrNi3O8  ...  1126.234230      0.200000         0.250000
# 2        Cu3Sb(PO4)4  ...  2083.089272      0.000000         0.142857
# 3          LiCu(HO)4  ...  1503.189668      0.100000         0.181818
# 4     Mn3CuNi2(PO4)6  ...  1452.065776      0.000000         0.100000
# ...              ...  ...          ...           ...              ...
# 2435             VO2  ...   382.085393      0.000000         0.040000
# 2436            V3O7  ...  1890.562742      0.000000         0.166667
# 2437            V2O5  ...  1554.658080      0.000000         0.125000
# 2438            V2O5  ...  1114.284551      0.000000         0.086957
# 2439            V2O5  ...  1858.968532      0.000000         0.155172
#
#       stability_charge  stability_discharge  \
# 0             0.037008             0.010849
# 1             0.089504             0.038122
# 2             0.067563             0.072026
# 3             0.078001             0.080676
# 4             0.045275             0.082965
# ...                ...                  ...
# 2435          0.137107             0.130874
# 2436          0.082159             0.067151
# 2437          0.012942             0.025422
# 2438          0.029818             0.034136
# 2439          0.025970             0.049371
#
#                                          host_structure  \
# 0     {'@module': 'pymatgen.core.structure', '@class...
# 1     {'@module': 'pymatgen.core.structure', '@class...
# 2     {'@module': 'pymatgen.core.structure', '@class...
# 3     {'@module': 'pymatgen.core.structure', '@class...
# 4     {'@module': 'pymatgen.core.structure', '@class...
# ...                                                 ...
# 2435  {'@module': 'pymatgen.core.structure', '@class...
# 2436  {'@module': 'pymatgen.core.structure', '@class...
# 2437  {'@module': 'pymatgen.core.structure', '@class...
# 2438  {'@module': 'pymatgen.core.structure', '@class...
# 2439  {'@module': 'pymatgen.core.structure', '@class...
#
#                                               adj_pairs  \
# 0     [{'formula_charge': 'Li2CoNi3O8', 'formula_dis...
# 1     [{'formula_charge': 'Li3CrNi3O8', 'formula_dis...
# 2     [{'formula_charge': 'Cu3Sb(PO4)4', 'formula_di...
# 3     [{'formula_charge': 'LiCu(HO)4', 'formula_disc...
# 4     [{'formula_charge': 'Mn3CuNi2(PO4)6', 'formula...
# ...                                                 ...
# 2435  [{'formula_charge': 'VO2', 'formula_discharge'...
# 2436  [{'formula_charge': 'V3O7', 'formula_discharge...
# 2437  [{'formula_charge': 'V2O5', 'formula_discharge...
# 2438  [{'formula_charge': 'V2O5', 'formula_discharge...
# 2439  [{'formula_charge': 'V2O5', 'formula_discharge...
#
#                             entries_composition_summary  \
# 0     {'all_formulas': ['Li4CoNi3O8', 'Li2CoNi3O8', ...
# 1     {'all_formulas': ['Li4CrNi3O8', 'Li3CrNi3O8'],...
# 2     {'all_formulas': ['Li4Cu3Sb(PO4)4', 'Cu3Sb(PO4...
# 3     {'all_formulas': ['Li2Cu(HO)4', 'LiCu(HO)4'], ...
# 4     {'all_formulas': ['Mn3CuNi2(PO4)6', 'Li4Mn3CuN...
# ...                                                 ...
# 2435  {'all_formulas': ['VO2', 'LiV8O16'], 'all_chem...
# 2436  {'all_formulas': ['Li2V3O7', 'V3O7'], 'all_che...
# 2437  {'all_formulas': ['V2O5', 'LiV2O5'], 'all_chem...
# 2438  {'all_formulas': ['Li2V6O15', 'V2O5', 'LiV4O10...
# 2439  {'all_formulas': ['V2O5', 'Li9V14O35'], 'all_c...
#
#                                        electrode_object  \
# 0     {'voltage_pairs': [{'voltage': 3.7556553933333...
# 1     {'voltage_pairs': [{'voltage': 3.5559580133333...
# 2     {'voltage_pairs': [{'voltage': 3.6375136033333...
# 3     {'voltage_pairs': [{'voltage': 2.9016335933333...
# 4     {'voltage_pairs': [{'voltage': 3.7576910933333...
# ...                                                 ...
# 2435  {'voltage_pairs': [{'voltage': 2.7833067433333...
# 2436  {'voltage_pairs': [{'voltage': 3.2735610533333...
# 2437  {'voltage_pairs': [{'voltage': 3.4979915308333...
# 2438  {'voltage_pairs': [{'voltage': 3.6917310599999...
# 2439  {'voltage_pairs': [{'voltage': 3.3152881672222...
#
#                  fields_not_requested
# 0     ['battery_type', 'thermo_type']
# 1     ['battery_type', 'thermo_type']
# 2     ['battery_type', 'thermo_type']
# 3     ['battery_type', 'thermo_type']
# 4     ['battery_type', 'thermo_type']
# ...                               ...
# 2435  ['battery_type', 'thermo_type']
# 2436  ['battery_type', 'thermo_type']
# 2437  ['battery_type', 'thermo_type']
# 2438  ['battery_type', 'thermo_type']
# 2439  ['battery_type', 'thermo_type']
#
# [2440 rows x 26 columns]

# %%
# データ確認
df.shape

# %%
# データ情報
df.info()

# %%
# データ保存
clean_df.to_csv("Li_battery_data.csv",index=False)
